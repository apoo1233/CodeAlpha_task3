# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("/content/student_performance.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df = pd.read_csv("/content/student_performance.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance  Math  Science  English  \
# 0           1  Female   18            4          85    78       82       75
# 1           2    Male   19            2          70    65       68       60
# 2           3  Female   18            5          92    88       90       86
# 3           4    Male   20            3          75    70       72       68
# 4           5  Female   18            6          95    92       94       90
#
#    Average_Marks
# 0      78.333333
# 1      64.333333
# 2      88.000000
# 3      70.000000
# 4      92.000000

# %%
df["Average_Marks"] = df[["Math", "Science", "English"]].mean(axis=1)

df.head()
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance  Math  Science  English  \
# 0           1  Female   18            4          85    78       82       75
# 1           2    Male   19            2          70    65       68       60
# 2           3  Female   18            5          92    88       90       86
# 3           4    Male   20            3          75    70       72       68
# 4           5  Female   18            6          95    92       94       90
#
#    Average_Marks
# 0      78.333333
# 1      64.333333
# 2      88.000000
# 3      70.000000
# 4      92.000000

# %%
subject_avg = df[["Math", "Science", "English"]].mean()

plt.figure(figsize=(8,5))
plt.bar(subject_avg.index, subject_avg.values)

plt.title("Average Marks by Subject")
plt.xlabel("Subject")
plt.ylabel("Average Marks")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Study_Hours"], df["Average_Marks"])

plt.title("Study Hours vs Average Marks")
plt.xlabel("Study Hours")
plt.ylabel("Average Marks")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Attendance"], df["Average_Marks"])

plt.title("Attendance vs Average Marks")
plt.xlabel("Attendance (%)")
plt.ylabel("Average Marks")

plt.show()

# %%
gender_count = df["Gender"].value_counts()

plt.figure(figsize=(6,6))
plt.pie(
    gender_count.values,
    labels=gender_count.index,
    autopct="%1.1f%%"
)

plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Math"], bins=10)

plt.title("Distribution of Mathematics Marks")
plt.xlabel("Math Marks")
plt.ylabel("Number of Students")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df[["Math", "Science", "English"]])

plt.title("Distribution of Marks by Subject")
plt.xlabel("Subject")
plt.ylabel("Marks")

plt.show()

# %%
gender_avg = df.groupby("Gender")["Average_Marks"].mean()

plt.figure(figsize=(7,5))
plt.bar(gender_avg.index, gender_avg.values)

plt.title("Average Marks by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Marks")

plt.show()

# %%
plt.figure(figsize=(10,7))

correlation = df[
    ["Study_Hours", "Attendance", "Math", "Science", "English", "Average_Marks"]
].corr()

sns.heatmap(correlation, annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Student Performance Data Visualization Using Python
#
# ## Objective
#
# The objective of this project is to analyze student performance data using different data visualization techniques. The project uses Python, Pandas, Matplotlib and Seaborn to create meaningful visualizations and identify patterns in student academic performance.

# %% [markdown]
# ## Visualizations Created
#
# 1. Average Marks by Subject
# 2. Study Hours vs Average Marks
# 3. Attendance vs Average Marks
# 4. Gender Distribution
# 5. Distribution of Mathematics Marks
# 6. Subject Marks Distribution
# 7. Average Marks by Gender
# 8. Correlation Heatmap

# %% [markdown]
# ## Observations
#
# 1. The average marks of Mathematics, Science and English were compared.
# 2. The relationship between study hours and average marks was visualized.
# 3. Attendance and academic performance were compared using a scatter plot.
# 4. The gender distribution of students was represented using a pie chart.
# 5. The distribution of Mathematics marks was examined using a histogram.
# 6. Boxplots were used to understand the spread of marks and identify possible outliers.
# 7. Average marks were compared between gender groups.
# 8. The correlation heatmap helped identify relationships between numerical variables.

# %% [markdown]
# ## Conclusion
#
# Data visualization helped transform the student performance data into easy-to-understand graphical representations. Different charts were used to analyze subject performance, study hours, attendance and other factors. The visualizations made it easier to identify patterns, relationships and differences in the dataset. Python libraries such as Pandas, Matplotlib and Seaborn were useful for performing the analysis and creating the visualizations.
